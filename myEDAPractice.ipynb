# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
mean_bore = df['bore'].astype('float').mean(axis=0)
mean_stroke = df['stroke'].astype('float').mean(axis=0)
mean_hp = df['horsepower'].astype('float').mean(axis=0)

# %%
df.replace('?',np.NaN,inplace=True)

# %%
df['bore'].replace(np.NaN,mean_bore,inplace=True)
df['stroke'].replace(np.NaN,mean_stroke,inplace=True)
df['horsepower'].replace(np.NaN,mean_hp,inplace=True)

# %%
df[df['price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [symboling, normalized-losses, make, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price, city-L/100km, horsepower-binned, diesel, gas]
# Index: []
#
# [0 rows x 29 columns]

# %%
numeric_df = df.select_dtypes(include=['float','int'])

# %%
numeric_df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
sns.regplot(x="engine-size",y="price",data=df)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
sns.regplot(x="horsepower",y="price",data=df)
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %%
sns.regplot(x="engine-size",y="price",data=df)
# Out:
# <Axes: xlabel='engine-size', ylabel='price'>

# %%
sns.regplot(x="highway-mpg",y="price",data=numeric_df)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
sns.boxplot(x="body-style", y="price",data=df)
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
sns.boxplot(x="engine-location",y="price",data=df)
# Out:
# <Axes: xlabel='engine-location', ylabel='price'>

# %%
df[["wheel-base","price"]].corr()
# Out:
#             wheel-base     price
# wheel-base    1.000000  0.584642
# price         0.584642  1.000000

# %%
df.head(1)
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# 0                9.0       111.0    5000.0       21          27  13495.0
#
#   city-L/100km  horsepower-binned  diesel  gas
# 0    11.190476             Medium       0    1
#
# [1 rows x 29 columns]

# %%
sns.boxplot(x="drive-wheels",y="price",data=df)
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %%
plt.figure(figsize=(24,12))
sns.boxplot(x="make",y="price",data=df)
plt.show()

# %%
bins = np.linspace(df['price'].min(),df['price'].max(),4)
names = ['low_price','medium_price','high_price']
df['price_range']=pd.cut(df['price'],bins,labels=names)

# %%
df[df['horsepower-binned'] == 'Low']
# Out:
#      symboling  normalized-losses        make aspiration num-of-doors  \
# 9            2                192         bmw        std          two
# 10           0                192         bmw        std         four
# 17           2                121   chevrolet        std          two
# 18           1                 98   chevrolet        std          two
# 19           0                 81   chevrolet        std         four
# ..         ...                ...         ...        ...          ...
# 184          2                 94  volkswagen        std         four
# 185          3                122  volkswagen        std          two
# 186          3                256  volkswagen        std          two
# 188          0                122  volkswagen      turbo         four
# 189          0                122  volkswagen        std         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
df_test = df[['drive-wheels','body-style','price']]
df_grpby = df_test.groupby(['drive-wheels','body-style'],as_index=False)['price'].sum()
df_grpby
# Out:
#    drive-wheels   body-style     price
# 0           4wd    hatchback    7603.0
# 1           4wd        sedan   37942.0
# 2           4wd        wagon   36383.0
# 3           fwd  convertible   11595.0
# 4           fwd      hardtop    8249.0
# 5           fwd    hatchback  411423.0
# 6           fwd        sedan  539649.0
# 7           fwd        wagon  119968.0
# 8           rwd  convertible  119748.0
# 9           rwd      hardtop  169419.0
# 10          rwd    hatchback  258080.0
# 11          rwd        sedan  781626.0
# 12          rwd        wagon  152948.0

# %%
df_pivot = df_grpby.pivot(index='drive-wheels',columns=['body-style'])
df_pivot.fillna(0)
# Out:
#                    price
# body-style   convertible   hardtop hatchback     sedan     wagon
# drive-wheels
# 4wd                  0.0       0.0    7603.0   37942.0   36383.0
# fwd              11595.0    8249.0  411423.0  539649.0  119968.0
# rwd             119748.0  169419.0  258080.0  781626.0  152948.0

# %%
df['engine-location'].value_counts()
df['make'].value_counts()
df_test1 = df[['engine-location', 'make', 'price']]
df_grp1 = df_test1.groupby(['engine-location','make'],as_index=False)['price'].sum()
df_grp1
# Out:
#    engine-location           make     price
# 0            front    alfa-romero   46495.0
# 1            front           audi  107155.0
# 2            front            bmw  208950.0
# 3            front      chevrolet   18021.0
# 4            front          dodge   70879.0
# 5            front          honda  106401.0
# 6            front          isuzu   17833.0
# 7            front         jaguar  103800.0
# 8            front          mazda  181099.0
# 9            front  mercedes-benz  269176.0
# 10           front        mercury   16503.0
# 11           front     mitsubishi  120117.0
# 12           front         nissan  187482.0
# 13           front         peugot  170380.0
# 14           front       plymouth   55744.0
# 15           front        porsche   22018.0
# 16           front        renault   19190.0
# 17           front           saab   91340.0
# 18           front         subaru  102495.0
# 19           front         toyota  316346.0
# ...

# %%
df_pivot1 = df_grp1.pivot(index=['make'],columns=['engine-location'])
df_pivot1 = df_pivot1.fillna(0)
df_pivot1
# Out:
#                     price
# engine-location     front      rear
# make
# alfa-romero       46495.0       0.0
# audi             107155.0       0.0
# bmw              208950.0       0.0
# chevrolet         18021.0       0.0
# dodge             70879.0       0.0
# honda            106401.0       0.0
# isuzu             17833.0       0.0
# jaguar           103800.0       0.0
# mazda            181099.0       0.0
# mercedes-benz    269176.0       0.0
# mercury           16503.0       0.0
# mitsubishi       120117.0       0.0
# nissan           187482.0       0.0
# peugot           170380.0       0.0
# plymouth          55744.0       0.0
# porsche           22018.0  103584.0
# renault           19190.0       0.0
# saab              91340.0       0.0
# subaru           102495.0       0.0
# toyota           316346.0       0.0
# volkswagen       120930.0       0.0
# volvo            198695.0       0.0

# %%
df_bd = df.groupby(['body-style'],as_index=False)['price'].mean()
df_bd.rename(columns={'price':'average_price'})
# Out:
#     body-style  average_price
# 0  convertible   21890.500000
# 1      hardtop   22208.500000
# 2    hatchback    9957.441176
# 3        sedan   14459.755319
# 4        wagon   12371.960000

# %%
df_pivot = df_pivot.fillna(0)
plt.pcolor(df_pivot, cmap = 'RdBu')
plt.colorbar()
plt.show()

# %%
df.select_dtypes(include=['float','int']).corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.007992           0.055127    0.157964  0.123913
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])
print ("Pearson Coef: ",pearson_coef, " P-Value: ", p_value)
# Out:
# Pearson Coef:  0.6906283804483639  P-Value:  8.016477466159241e-30

# %%
pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print ("Pearson Coef: ",pearson_coef, " P-Value: ", p_value)
# Out:
# Pearson Coef:  -0.7046922650589531  P-Value:  1.7495471144475605e-31
